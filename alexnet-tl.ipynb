# %%
# License: BSD
# Author: Sasank Chilamkurthy

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = '/kaggle/input/potholehumpvgg/customdataset'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, num_epochs=25):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'test']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'test' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
NUM_CLASSES = 2
model_ft = models.alexnet(pretrained = True)


# Freeze all layers except the last few
for param in model_ft.parameters():
    param.requires_grad = False

model_ft.classifier[6] = nn.Linear(model_ft.classifier[6].in_features, NUM_CLASSES)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.AdamW(model_ft.parameters(), lr=0.001)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 159MB/s]

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft,
                       num_epochs=100)
torch.save(model_ft.state_dict(), 'best_model.pth')
# Out:
# Epoch 0/99
# ----------
# train Loss: 0.1288 Acc: 0.9536
# test Loss: 1.0532 Acc: 0.6809
#
# Epoch 1/99
# ----------
# train Loss: 0.0940 Acc: 0.9675
# test Loss: 1.6465 Acc: 0.6809
#
# Epoch 2/99
# ----------
# train Loss: 0.0866 Acc: 0.9729
# test Loss: 1.5384 Acc: 0.7447
#
# Epoch 3/99
# ----------
# train Loss: 0.0908 Acc: 0.9754
# test Loss: 1.6584 Acc: 0.7021
#
# Epoch 4/99
# ----------
# train Loss: 0.0834 Acc: 0.9775
# test Loss: 2.4500 Acc: 0.6596
#
# Epoch 5/99
# ----------
# train Loss: 0.1013 Acc: 0.9719
# test Loss: 1.8510 Acc: 0.7447
#
# Epoch 6/99
# ----------
# train Loss: 0.0651 Acc: 0.9794
# test Loss: 2.1126 Acc: 0.6809
#
# Epoch 7/99
# ----------
# train Loss: 0.0888 Acc: 0.9784
# test Loss: 2.3767 Acc: 0.5957
#
# Epoch 8/99
# ----------
# train Loss: 0.0889 Acc: 0.9771
# test Loss: 2.2889 Acc: 0.6596
#
# Epoch 9/99
# ----------
# train Loss: 0.0944 Acc: 0.9788
# test Loss: 2.2541 Acc: 0.7021
#
# Epoch 10/99
# ----------
# train Loss: 0.0989 Acc: 0.9765
# test Loss: 2.8202 Acc: 0.6383
#
# Epoch 11/99
# ----------
# train Loss: 0.0843 Acc: 0.9811
# test Loss: 2.9490 Acc: 0.7021
#
# Epoch 12/99
# ----------
# train Loss: 0.0683 Acc: 0.9840
# test Loss: 4.7057 Acc: 0.5957
#
# Epoch 13/99
# ----------
# train Loss: 0.1007 Acc: 0.9813
# test Loss: 2.5390 Acc: 0.6596
#
# Epoch 14/99
# ----------
# train Loss: 0.0893 Acc: 0.9802
# test Loss: 2.8075 Acc: 0.6809
#
# Epoch 15/99
# ----------
# train Loss: 0.1091 Acc: 0.9754
# test Loss: 2.0042 Acc: 0.6170
#
# Epoch 16/99
# ----------
# train Loss: 0.0603 Acc: 0.9865
# test Loss: 1.8939 Acc: 0.6809
#
# Epoch 17/99
# ----------
# train Loss: 0.0751 Acc: 0.9815
# test Loss: 2.9266 Acc: 0.6809
#
# Epoch 18/99
# ----------
# train Loss: 0.0932 Acc: 0.9815
# test Loss: 3.2202 Acc: 0.6383
#
# Epoch 19/99
# ----------
# train Loss: 0.0893 Acc: 0.9831
# test Loss: 2.4315 Acc: 0.6809
#
# Epoch 20/99
# ----------
# train Loss: 0.0946 Acc: 0.9833
# test Loss: 2.1551 Acc: 0.7660
#
# Epoch 21/99
# ----------
# train Loss: 0.0944 Acc: 0.9788
# test Loss: 3.8903 Acc: 0.6170
#
# Epoch 22/99
# ----------
# train Loss: 0.0923 Acc: 0.9794
# test Loss: 2.2353 Acc: 0.7234
#
# Epoch 23/99
# ----------
# train Loss: 0.0882 Acc: 0.9829
# test Loss: 3.1939 Acc: 0.6809
#
# Epoch 24/99
# ----------
# train Loss: 0.0828 Acc: 0.9825
# test Loss: 2.5738 Acc: 0.6596
#
# Epoch 25/99
# ----------
# train Loss: 0.0960 Acc: 0.9831
# test Loss: 2.5786 Acc: 0.7021
#
# Epoch 26/99
# ----------
# train Loss: 0.0899 Acc: 0.9827
# test Loss: 1.9631 Acc: 0.8085
#
# Epoch 27/99
# ----------
# train Loss: 0.0918 Acc: 0.9792
# test Loss: 2.9220 Acc: 0.6170
#
# Epoch 28/99
# ----------
# train Loss: 0.0756 Acc: 0.9831
# test Loss: 2.9091 Acc: 0.6383
#
# Epoch 29/99
# ----------
# train Loss: 0.0649 Acc: 0.9836
# test Loss: 2.8018 Acc: 0.7234
#
# Epoch 30/99
# ----------
# train Loss: 0.0918 Acc: 0.9825
# test Loss: 3.1471 Acc: 0.6596
#
# Epoch 31/99
# ----------
# train Loss: 0.0865 Acc: 0.9819
# test Loss: 3.0019 Acc: 0.6383
#
# Epoch 32/99
# ----------
# train Loss: 0.0746 Acc: 0.9838
# test Loss: 2.9228 Acc: 0.6596
#
# Epoch 33/99
# ----------
# train Loss: 0.0821 Acc: 0.9846
# test Loss: 2.2572 Acc: 0.7447
#
# Epoch 34/99
# ----------
# train Loss: 0.0741 Acc: 0.9825
# test Loss: 2.3794 Acc: 0.7234
#
# Epoch 35/99
# ----------
# train Loss: 0.0752 Acc: 0.9838
# test Loss: 3.1636 Acc: 0.6596
#
# Epoch 36/99
# ----------
# train Loss: 0.0903 Acc: 0.9850
# test Loss: 1.9623 Acc: 0.7447
#
# Epoch 37/99
# ----------
# train Loss: 0.0647 Acc: 0.9861
# test Loss: 2.7073 Acc: 0.6383
#
# Epoch 38/99
# ----------
# train Loss: 0.0750 Acc: 0.9838
# test Loss: 3.1467 Acc: 0.6596
#
# Epoch 39/99
# ----------
# train Loss: 0.0908 Acc: 0.9833
# test Loss: 2.7031 Acc: 0.7447
#
# Epoch 40/99
# ----------
# train Loss: 0.0934 Acc: 0.9842
# test Loss: 3.2121 Acc: 0.6170
#
# Epoch 41/99
# ----------
# train Loss: 0.0782 Acc: 0.9861
# test Loss: 3.0621 Acc: 0.6383
#
# Epoch 42/99
# ----------
# train Loss: 0.0752 Acc: 0.9842
# test Loss: 2.1536 Acc: 0.7234
#
# Epoch 43/99
# ----------
# train Loss: 0.0756 Acc: 0.9848
# test Loss: 4.2216 Acc: 0.5957
#
# Epoch 44/99
# ----------
# train Loss: 0.0958 Acc: 0.9833
# test Loss: 3.0131 Acc: 0.6383
#
# Epoch 45/99
# ----------
# train Loss: 0.0788 Acc: 0.9817
# test Loss: 3.7019 Acc: 0.6170
#
# Epoch 46/99
# ----------
# train Loss: 0.0811 Acc: 0.9833
# test Loss: 3.6615 Acc: 0.6383
#
# Epoch 47/99
# ----------
# train Loss: 0.0955 Acc: 0.9833
# test Loss: 3.3368 Acc: 0.6170
#
# Epoch 48/99
# ----------
# train Loss: 0.0792 Acc: 0.9825
# test Loss: 4.0616 Acc: 0.6383
#
# Epoch 49/99
# ----------
# train Loss: 0.0797 Acc: 0.9865
# test Loss: 4.0181 Acc: 0.6596
#
# Epoch 50/99
# ----------
# train Loss: 0.0879 Acc: 0.9852
# test Loss: 2.7320 Acc: 0.7021
#
# Epoch 51/99
# ----------
# train Loss: 0.0989 Acc: 0.9811
# test Loss: 3.3189 Acc: 0.7021
#
# Epoch 52/99
# ----------
# train Loss: 0.0983 Acc: 0.9823
# test Loss: 2.4441 Acc: 0.7021
#
# Epoch 53/99
# ----------
# train Loss: 0.0572 Acc: 0.9873
# test Loss: 4.0328 Acc: 0.6383
#
# Epoch 54/99
# ----------
# train Loss: 0.0796 Acc: 0.9829
# test Loss: 4.0631 Acc: 0.5957
#
# Epoch 55/99
# ----------
# train Loss: 0.0713 Acc: 0.9850
# test Loss: 3.0052 Acc: 0.6809
#
# Epoch 56/99
# ----------
# train Loss: 0.0818 Acc: 0.9829
# test Loss: 2.8880 Acc: 0.6809
#
# Epoch 57/99
# ----------
# train Loss: 0.1182 Acc: 0.9808
# test Loss: 4.0392 Acc: 0.5957
#
# Epoch 58/99
# ----------
# train Loss: 0.0721 Acc: 0.9861
# test Loss: 2.6144 Acc: 0.7021
#
# Epoch 59/99
# ----------
# train Loss: 0.0643 Acc: 0.9875
# test Loss: 2.2580 Acc: 0.7447
#
# Epoch 60/99
# ----------
# train Loss: 0.0701 Acc: 0.9863
# test Loss: 2.9182 Acc: 0.7021
#
# Epoch 61/99
# ----------
# train Loss: 0.0935 Acc: 0.9850
# test Loss: 2.5647 Acc: 0.6809
#
# Epoch 62/99
# ----------
# train Loss: 0.1155 Acc: 0.9806
# test Loss: 2.4371 Acc: 0.7234
#
# Epoch 63/99
# ----------
# train Loss: 0.0717 Acc: 0.9856
# test Loss: 2.7465 Acc: 0.6170
#
# Epoch 64/99
# ----------
# train Loss: 0.0630 Acc: 0.9854
# test Loss: 2.6430 Acc: 0.7234
#
# Epoch 65/99
# ----------
# train Loss: 0.0828 Acc: 0.9861
# test Loss: 3.4558 Acc: 0.6170
#
# Epoch 66/99
# ----------
# train Loss: 0.0900 Acc: 0.9848
# test Loss: 3.0684 Acc: 0.6383
#
# Epoch 67/99
# ----------
# train Loss: 0.0882 Acc: 0.9858
# test Loss: 3.6710 Acc: 0.6383
#
# Epoch 68/99
# ----------
# train Loss: 0.0777 Acc: 0.9856
# test Loss: 2.8380 Acc: 0.7234
#
# Epoch 69/99
# ----------
# train Loss: 0.0778 Acc: 0.9858
# test Loss: 3.3378 Acc: 0.6596
#
# Epoch 70/99
# ----------
# train Loss: 0.0842 Acc: 0.9844
# test Loss: 1.9433 Acc: 0.7872
#
# Epoch 71/99
# ----------
# train Loss: 0.0835 Acc: 0.9854
# test Loss: 2.4470 Acc: 0.7447
#
# Epoch 72/99
# ----------
# train Loss: 0.1040 Acc: 0.9827
# test Loss: 2.2772 Acc: 0.7447
#
# Epoch 73/99
# ----------
# train Loss: 0.1034 Acc: 0.9825
# test Loss: 2.0154 Acc: 0.8511
#
# Epoch 74/99
# ----------
# train Loss: 0.0921 Acc: 0.9831
# test Loss: 2.8781 Acc: 0.6809
#
# Epoch 75/99
# ----------
# train Loss: 0.0727 Acc: 0.9861
# test Loss: 1.7991 Acc: 0.7660
#
# Epoch 76/99
# ----------
# train Loss: 0.0897 Acc: 0.9831
# test Loss: 2.3321 Acc: 0.7021
#
# Epoch 77/99
# ----------
# train Loss: 0.0764 Acc: 0.9863
# test Loss: 2.2979 Acc: 0.7447
#
# Epoch 78/99
# ----------
# train Loss: 0.0690 Acc: 0.9879
# test Loss: 1.8350 Acc: 0.7447
#
# Epoch 79/99
# ----------
# train Loss: 0.0739 Acc: 0.9852
# test Loss: 3.4421 Acc: 0.5957
#
# Epoch 80/99
# ----------
# train Loss: 0.0912 Acc: 0.9829
# test Loss: 2.9127 Acc: 0.6596
#
# Epoch 81/99
# ----------
# train Loss: 0.0727 Acc: 0.9861
# test Loss: 3.3087 Acc: 0.6596
#
# Epoch 82/99
# ----------
# train Loss: 0.0970 Acc: 0.9829
# test Loss: 2.3098 Acc: 0.7447
#
# Epoch 83/99
# ----------
# train Loss: 0.0658 Acc: 0.9854
# test Loss: 2.6322 Acc: 0.7660
#
# Epoch 84/99
# ----------
# train Loss: 0.0686 Acc: 0.9858
# test Loss: 3.4915 Acc: 0.6383
#
# Epoch 85/99
# ----------
# train Loss: 0.0815 Acc: 0.9848
# test Loss: 3.3489 Acc: 0.7872
#
# Epoch 86/99
# ----------
# train Loss: 0.0631 Acc: 0.9861
# test Loss: 3.2025 Acc: 0.7447
#
# Epoch 87/99
# ----------
# train Loss: 0.1023 Acc: 0.9846
# test Loss: 3.4213 Acc: 0.6596
#
# Epoch 88/99
# ----------
# train Loss: 0.0488 Acc: 0.9875
# test Loss: 2.9449 Acc: 0.7660
#
# Epoch 89/99
# ----------
# train Loss: 0.0534 Acc: 0.9888
# test Loss: 2.5686 Acc: 0.7234
#
# Epoch 90/99
# ----------
# train Loss: 0.0855 Acc: 0.9879
# test Loss: 2.6758 Acc: 0.7021
#
# Epoch 91/99
# ----------
# train Loss: 0.0757 Acc: 0.9858
# test Loss: 3.5789 Acc: 0.6596
#
# Epoch 92/99
# ----------
# train Loss: 0.0842 Acc: 0.9811
# test Loss: 3.2094 Acc: 0.6596
#
# Epoch 93/99
# ----------
# train Loss: 0.0595 Acc: 0.9877
# test Loss: 3.3092 Acc: 0.6596
#
# Epoch 94/99
# ----------
# train Loss: 0.0685 Acc: 0.9846
# test Loss: 3.5060 Acc: 0.6809
#
# Epoch 95/99
# ----------
# train Loss: 0.1068 Acc: 0.9844
# test Loss: 3.2262 Acc: 0.7021
#
# Epoch 96/99
# ----------
# train Loss: 0.1015 Acc: 0.9819
# test Loss: 3.7588 Acc: 0.6809
#
# Epoch 97/99
# ----------
# train Loss: 0.0898 Acc: 0.9840
# test Loss: 2.3785 Acc: 0.6383
#
# Epoch 98/99
# ----------
# train Loss: 0.0664 Acc: 0.9869
# test Loss: 2.3642 Acc: 0.7447
#
# Epoch 99/99
# ----------
# train Loss: 0.0902 Acc: 0.9842
# test Loss: 3.5030 Acc: 0.6809
#
# Training complete in 53m 52s
# Best val Acc: 0.851063829787234

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
classes = ['hump', 'pothole']

# %%
image_dataset = datasets.ImageFolder('/kaggle/input/vggtest/vggtest',
                                          data_transforms['test'])
test_loader = torch.utils.data.DataLoader(image_dataset, batch_size=4,
                                             shuffle=True, num_workers=4)

# %%
model_ft.load_state_dict(torch.load('best_model.pth'))
model_ft.eval()
correct = 0
total = 0
predictions = []
true_labels = []
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_ft(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        predictions.extend(predicted.tolist())
        true_labels.extend(labels.tolist())

# Convert predictions and true labels to numpy arrays
predictions = np.array(predictions)
true_labels = np.array(true_labels)



test_accuracy = correct / total
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Accuracy: 0.9570552147239264

# %%
# Calculate the confusion matrix
cm = confusion_matrix(true_labels, predictions)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(true_labels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96        83
#            1       0.93      0.99      0.96        80
#
#     accuracy                           0.96       163
#    macro avg       0.96      0.96      0.96       163
# weighted avg       0.96      0.96      0.96       163

# %%
import torch.nn.functional as F

# %%
# Load and transform the image
image_path = '/kaggle/input/testingimage/testingimage/Image_6 (1).jpg'
image = Image.open(image_path)
input_image = data_transforms['test'](image).unsqueeze(0)

# Move the input image tensor to the same device as the model
input_image = input_image.to(device)

# Perform inference
model_ft.eval()
with torch.no_grad():
    output = model_ft(input_image)

# Apply softmax to obtain probabilities
probabilities = F.softmax(output, dim=1)

# Get the predicted class index
_, predicted = torch.max(output, 1)
predicted_class_index = predicted.item()

# Assuming you have a list of class names
# Replace with your class names
classes = ['hump', 'pothole']
predicted_label = classes[predicted_class_index]

# Get the probability of the predicted class
predicted_probability = probabilities[:, predicted_class_index].item()

print(f"Predicted class: {predicted_label}")
print(f"Probability: {predicted_probability}")
print(f"All probabilities: {probabilities.squeeze().tolist()}")
# Out:
# Predicted class: pothole
# Probability: 1.0
# All probabilities: [1.34783703449013e-28, 1.0]

# %%
# Load and transform the image
image_path = '/kaggle/input/testingimage/testingimage/Copy of IMG_20240229_080519.jpg'
image = Image.open(image_path)
input_image = data_transforms['test'](image).unsqueeze(0)

# Move the input image tensor to the same device as the model
input_image = input_image.to(device)

# Perform inference
model_ft.eval()
with torch.no_grad():
    output = model_ft(input_image)

# Apply softmax to obtain probabilities
probabilities = F.softmax(output, dim=1)

# Get the predicted class index
_, predicted = torch.max(output, 1)
predicted_class_index = predicted.item()

# Assuming you have a list of class names
# Replace with your class names
classes = ['hump', 'pothole']
predicted_label = classes[predicted_class_index]

# Get the probability of the predicted class
predicted_probability = probabilities[:, predicted_class_index].item()

print(f"Predicted class: {predicted_label}")
print(f"Probability: {predicted_probability}")
print(f"All probabilities: {probabilities.squeeze().tolist()}")
# Out:
# Predicted class: hump
# Probability: 0.9999961853027344
# All probabilities: [0.9999961853027344, 3.8032583233871264e-06]
